# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
import numpy.random as rand

# %%
x = [1, 2]
y = [1, 2]

# %%
plt.title('Plotting these values')

# %%
plt.xlabel('x axis')
plt.ylabel('y axis')

# %%
plt.plot(x, y, label='x and y')
plt.plot(x, [3, 4], 'r--', label='other')
plt.legend()
plt.show()

# %%
# Scatter plots
mu1, mu2 = 2, 5
std = 1
sample1 = rand.normal(mu1, std, 50)
sample2 = rand.normal(mu2, std, 50)

# %%
sample1
# Out:
# array([ 1.0718728 ,  2.79871185,  2.82687356,  2.45575173,  2.50721761,
#         1.79813134,  2.38692508,  3.67574267,  2.00659506,  1.25374089,
#         1.88034517,  2.09729078,  1.87534485,  2.60315535,  0.55585881,
#         2.66859596,  3.03670248,  1.27696052,  0.81729743,  2.50535012,
#         3.83873706,  2.46201641,  0.74869762,  0.82800161,  3.58692548,
#         1.75682498,  3.34935541,  1.96195781,  2.98605497,  1.10436656,
#         4.79111565,  0.11692605,  1.43526123,  2.39389373,  2.02096596,
#         3.36717067,  1.50486486,  1.0812281 ,  1.12664647,  0.44240829,
#         1.34999572,  2.09311807,  1.94756384,  1.37180806,  2.36888889,
#        -0.2403635 ,  1.20022597,  2.03788978,  1.50686053,  2.115298  ])

# %%
sample1.shape
# Out:
# (50,)

# %%
fig = plt.gcf()
fig.gca().add_artist(plt.Circle((mu1, mu1), radius=std, color='b', fill=False))
fig.gca().add_artist(plt.Circle((mu2, mu2), radius=std, color='g', fill=False))

plt.plot(sample1[:25], sample1[25:], 'b*')
plt.plot(sample2[:25], sample2[25:], 'gD')

# %%
# Plotting over images
from skimage import data
from skimage import io

# %%
lena = data.lena()
plt.figure(1)
plt.axis('off')
plt.imshow(lena)
corners = np.array([
    [250, 250],
    [250, 370],
    [370, 370],
    [370, 250],
    [250, 250]
])
plt.plot(corners[:, 0], corners[:, 1], 'b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-28a12a88810e> in <module>()
# ----> 1 lena = data.lena()
#       2 plt.figure(1)
#       3 plt.axis('off')
#       4 plt.imshow(lena)
#       5 corners = np.array([
#
# AttributeError: module 'skimage.data' has no attribute 'lena'
